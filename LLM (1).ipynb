# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 22.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.

# %%
from google import genai
from google.colab import userdata

API_KEY = userdata.get("Gemini_API_Key")

client = genai.Client(api_key=API_KEY)

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
from google import genai
from google.colab import userdata

API_KEY = userdata.get("Gemini_API_Key")

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Explain Python in simple words."
)

print(response.text)
# Out:
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Think of **Python** as a way to talk to computers and tell them what to do.
#
# If computers speak "machine language" (which is just a bunch of 1s and 0s), Python is like a **friendly translator**. It lets you write instructions in a way that looks almost like plain English.
#
# Here is a simple way to understand it:
#
# ### 1. It’s like writing a recipe
# When you code in Python, you are basically writing a step-by-step recipe for the computer.
# * *For example, if you want the computer to say hello, you just write:*
#   `print("Hello!")`
#   That's it!
#
# ### 2. Why is it so popular?
# * **It’s easy to learn:** Unlike other coding languages that look like complicated math or alien symbols, Python is clean and readable. It’s usually the first language people learn.
# * **It’s a "Swiss Army Knife":** You can use Python for almost anything.
# * **It has a huge community:** Millions of people use it, so if you get stuck, the answer is always free on the internet.
#
# ### 3. What can you build with Python?
# Python is behind a lot of the technology you use every day:
# * **Artificial Intelligence & AI:** Tools like ChatGPT and self-driving cars use Python.
# * **Websites:** YouTube, Instagram, and Netflix use Python to run their platforms.
# * **Data & Science:** NASA uses Python to analyze space data.
# * **Automating Boring Tasks:** You can write a Python script to automatically sort your files, rename hundreds of photos, or fill out spreadsheets in seconds.
# * **Video Games:** You can use it to build simple 2D and 3D games.
#
# ### Summary
# If programming languages were vehicles, some would be like complex, hard-to-drive manual race cars. **Python is like a smooth, automatic car with GPS.** It gets you where you want to go easily and safely.
