# %%
# !pip install -U langchain-groq
# !pip install -U langchain

from google.colab import userdata
from langchain_groq import ChatGroq

GROQ_API_KEY = userdata.get('TejaswiniPatil')

groq_model = ChatGroq(model="openai/gpt-oss-20b",groq_api_key=GROQ_API_KEY)
prompt_text = "I want to open an Indian TV show. Suggest five creative names."
response = groq_model.invoke(prompt_text)
print(response.content)
# Out:
# ...
# Here are five fresh, eye‑catching titles that feel distinctly Indian while still sounding modern and memorable:
#
# | # | Show Title | Why it Works |
# |---|------------|--------------|
# | 1 | **“Desh‑Mela”** | Combines “Desh” (country) with “Mela” (fair), hinting at a vibrant, culturally rich journey across India. |
# | 2 | **“Rang Rashtra”** | “Rang” (color) + “Rashtra” (nation) evokes a colorful tapestry of stories from every corner of the country. |
# | 3 | **“Kahani Ki Kashti”** | “Kahani” (story) + “Kashti” (boat) suggests a voyage through tales that keep viewers glued to their seats. |
# | 4 | **“Bharat Baat”** | A playful nod to “Bharat” (India) and “Baat” (talk), perfect for a talk‑show or reality series that dives into everyday Indian life. |
# ...
